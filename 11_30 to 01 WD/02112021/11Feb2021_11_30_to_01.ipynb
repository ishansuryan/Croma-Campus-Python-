# %%
def line(x):
    m = 0.5
    y = m * x
    return y

# %%
x_num = [3,40,7.95,11,20.2,0]
y_num = []

for i in x_num:
    z = line(i)
    y_num.append(z)

# %%
import matplotlib.pyplot as plt

plt.plot(x_num, y_num)
plt.show()

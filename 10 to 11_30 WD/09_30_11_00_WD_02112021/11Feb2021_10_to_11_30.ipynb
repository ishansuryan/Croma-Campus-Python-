# %%
def line(x,c):
    m = .3
    y = m * x + c
    return y

# %%
import matplotlib.pyplot as plt

# %%
x_num = [1,32,36,85,5]
y_list = []

for i in x_num:
    z = line(i,0)
    y_list.append(z)

# %%
plt.plot(x_num,y_list, marker = )
plt.yticks([0,5,10,15,20,25,30])
plt.show()

# %%
import re

# %%
s = 'hpw are you?'
pattern = '\w+(\S*)$'
x = re.search(pattern, s)
x
# Out:
# <re.Match object; span=(8, 12), match='you?'>

# %% [markdown]
# ## Write a Python program to search some literals strings in a string.
# Sample text : 'The quick brown fox jumps over the lazy dog.'
# Searched words : 'fox', 'dog', 'horse'

# %%
lst = ['fox', 'dog', 'horse']

string = 'The quick brown fox jumps over the lazy dog.'
count = 0
for i in lst:
    if string.find(i)>0:
        count += 1

print(count) 

if count == len(lst):
    print('all the literals are present')
else:
    print("All literals not present")
# Out:
# 2
# All literals not present

# %%
lst = [(10,30,10),(30,20,8),(40,4,100),(10,10,50)]
x = sorted(lst, key = lambda z:z[2])
x
# Out:
# [(30, 20, 8), (10, 30, 10), (10, 10, 50), (40, 4, 100)]

# %%
def srt(x):
    return x[1]

# %%
v = srt
v
# Out:
# <function __main__.srt(x)>

# %%
lst = [(10,30,10),(30,20,8),(40,4,100),(10,10,50)]
c = sorted(lst, key = srt)
c
# Out:
# [(40, 4, 100), (10, 10, 50), (30, 20, 8), (10, 30, 10)]

# %%
import matplotlib.pyplot as plt

# %%
plt.plot([0,1,5,8,3],[0,12,5,8,7], marker = '*')
plt.show()

# %%
plt.his

# %%
import numpy as np

# %%
l = [1,2,3,4,5,6,7,8,9]
np.cumsum(l)
# Out:
# array([ 1,  3,  6, 10, 15, 21, 28, 36, 45])

# %%
from sklearn.decomposition import PCA
from sklearn.datasets import fetch_openml

# %%
mnist = fetch_openml('mnist_784', version = 1)

# %%
x,y = np.array(mnist['data']), np.array(mnist['target'], dtype = np.int8)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y)

# %%
pca = PCA()
pca.fit(x_train)
d = np.argmax(np.cumsum(pca.explained_variance_ratio_)>=0.95)+1

# %%
d
# Out:
# 154

# %%
pca = PCA(n_components=0.99)
x_reduced = pca.fit_transform(x_train)
pca.n_components_
# Out:
# 331

# %%
np.sum(pca.explained_variance_ratio_)
# Out:
# 0.9900773464724381

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
x_features = [x for x in range(1,332)]

# %%
plt.imshow(x_train[0].reshape(-1,28))

# %%
pca.explained_variance_ratio_
# Out:
# array([0.09738318, 0.07147185, 0.06170209, 0.05426257, 0.04886671,
#        0.04287961, 0.03289771, 0.02876182, 0.02755362, 0.02344747,
#        0.02118051, 0.02034764, 0.01711714, 0.01688844, 0.01581037,
#        0.01484535, 0.01317661, 0.01270998, 0.011835  , 0.01153229,
#        0.010668  , 0.0100845 , 0.00959093, 0.00906843, 0.00878392,
#        0.00835496, 0.00812799, 0.00788815, 0.00747926, 0.00693144,
#        0.00658786, 0.00646719, 0.00600845, 0.00585054, 0.0056669 ,
#        0.00544375, 0.00503958, 0.00489242, 0.00475625, 0.00465702,
#        0.0045297 , 0.00447599, 0.00418496, 0.00395546, 0.00385747,
#        0.00375612, 0.00361965, 0.00350777, 0.00338609, 0.00320321,
#        0.00317696, 0.00310453, 0.00295876, 0.00286261, 0.00281476,
#        0.00271309, 0.00267409, 0.00256494, 0.00251471, 0.00244186,
#        0.00239838, 0.00237195, 0.00229634, 0.00220847, 0.00212765,
#        0.00206674, 0.00202038, 0.00195704, 0.00193249, 0.001892  ,
# ...

# %%
plt.figure(figsize=(8,8))
plt.plot(x_features, pca.explained_variance_ratio_[::-1],'k--')
plt.xlabel('Number of features')
plt.show()

# %%
from sklearn.decomposition import IncrementalPCA

# %%
sgd_pca = PCA(n_components  = 331, svd_solver = 'randomized')

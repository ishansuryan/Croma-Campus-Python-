# %%
import numpy as np

# %%
l = [1,2,3,4,5,6,7,8,9]
np.cumsum(l)
# Out:
# array([ 1,  3,  6, 10, 15, 21, 28, 36, 45])

# %%
from sklearn.decomposition import PCA
from sklearn.datasets import fetch_openml

# %%
mnist = fetch_openml('mnist_784', version = 1)

# %%
x,y = np.array(mnist['data']), np.array(mnist['target'], dtype = np.int8)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y)

# %%
pca = PCA()
pca.fit(x_train)
d = np.argmax(np.cumsum(pca.explained_variance_ratio_)>=0.95)+1

# %%
d
# Out:
# 154

# %%
pca = PCA(n_components=0.99)
x_reduced = pca.fit_transform(x_train)
pca.n_components_
# Out:
# 331

# %%
np.sum(pca.explained_variance_ratio_)
# Out:
# 0.9900897631481083

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
x_features = [x for x in range(1,332)]

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-ad0c1650de2d> in <module>
#       1 plt.figure(figsize=(8,8))
# ----> 2 plt.plot(x_features, pca.explained_variance_,'k--')
#       3 plt.xlabel('Number of features')
#       4 plt.show()
#
# /usr/lib/python3.9/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2986 @_copy_docstring_and_deprecators(Axes.plot)
#    2987 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2988     return gca().plot(
#    2989         *args, scalex=scalex, scaley=scaley,
#    2990         **({"data": data} if data is not None else {}), **kwargs)
#
# /usr/lib/python3.9/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1603         """
#    1604         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1605         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1606         for line in lines:
#    1607             self.add_line(line)
#
# /usr/lib/python3.9/site-packages/matplotlib/axes/_base.py in __call__(self, data, *args, **kwargs)
#     313                 this += args[0],
#     314                 args = args[1:]
# --> 315             yield from self._plot_args(this, kwargs)
#     316
#     317     def get_next_color(self):
#
# /usr/lib/python3.9/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs, return_kwargs)
#     499
#     500         if x.shape[0] != y.shape[0]:
# --> 501             raise ValueError(f"x and y must have same first dimension, but "
#     502                              f"have shapes {x.shape} and {y.shape}")
#     503         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (400,) and (331,)

# %%
plt.imshow(x_train[0].reshape(-1,28))

# %%
pca.explained_variance_ratio_
# Out:
# array([0.09727278, 0.07194834, 0.0614033 , 0.05416841, 0.04877829,
#        0.04307868, 0.03276771, 0.02876346, 0.02760994, 0.02346515,
#        0.02101725, 0.02039255, 0.01705198, 0.01697805, 0.01584286,
#        0.01491871, 0.01323354, 0.01278793, 0.01192341, 0.01149868,
#        0.01068793, 0.01013748, 0.00959012, 0.00906667, 0.00883778,
#        0.00839297, 0.00809473, 0.00788178, 0.00738614, 0.00689742,
#        0.00655734, 0.0064641 , 0.00599867, 0.00585763, 0.00567479,
#        0.00541838, 0.00507   , 0.00489113, 0.00476095, 0.00464543,
#        0.00452395, 0.00444435, 0.00417175, 0.00396245, 0.00383145,
#        0.0037478 , 0.00361383, 0.00347742, 0.00339958, 0.00320914,
#        0.00316814, 0.00309303, 0.00297708, 0.00287012, 0.00281973,
#        0.0026918 , 0.00268907, 0.0025624 , 0.0025312 , 0.00244909,
#        0.00239525, 0.00237052, 0.00229434, 0.00221323, 0.0021254 ,
#        0.00206208, 0.00203085, 0.00194802, 0.00190498, 0.00187895,
#        0.00186512, 0.00180551, 0.00175672, 0.00172005, 0.00164544,
#        0.00163792, 0.00160833, 0.00153479, 0.00146449, 0.00141847,
#        0.00141139, 0.00140476, 0.00139297, 0.00135371, 0.00131917,
#        0.00131259, 0.00129319, 0.00126007, 0.00123319, 0.00120254,
#        0.00116445, 0.00113736, 0.00112575, 0.00109821, 0.00107882,
#        0.00106496, 0.00103881, 0.00102986, 0.00100103, 0.00099963,
#        0.00097551, 0.0009421 , 0.00093187, 0.00090777, 0.0009002 ,
#        0.00088624, 0.00086065, 0.0008524 , 0.00084185, 0.0008194 ,
#        0.00079051, 0.00077932, 0.00077295, 0.00076195, 0.00076002,
#        0.00074928, 0.00073169, 0.00072032, 0.00071029, 0.0007052 ,
#        0.00069528, 0.00068443, 0.00067767, 0.00066934, 0.00066517,

# %%
import numpy as np
import matplotlib.pyplot as plt
import time

# %%
np.random.seed(42)
X = 2 * np.random.rand(100,1)

# %%
y = 4 + 3 * X + np.random.randn(100,1)
#               Gaussin Noise

# %%
plt.plot(X,y,'b.')
plt.xlabel('$X_1$', fontsize = 20)
plt.ylabel('y', rotation= 0, fontsize = 20)
plt.axis([0,2,0,15])
plt.show()

# %%
X_b = np.c_[np.ones((100,1)),X]

# %%
start = time.time()
time.sleep(1)
theta = np.linalg.inv(X_b.T.dot(X_b)).dot(X_b.T).dot(y)
print('time taken= ', time.time()-start)
# Out:
# time taken=  1.0132877826690674

# %%
theta
# Out:
# array([[4.21509616],
#        [2.77011339]])

# %%
X_new = np.array([[0],[2]])

# %%
X_new_b = np.c_[np.ones((2,1)),X_new]

# %%
y_new = X_new_b.dot(theta)
y_new
# Out:
# array([[4.21509616],
#        [9.75532293]])

# %%
plt.plot(X_new,y_new,'r-')
plt.plot(X,y,'b.')
plt.xlabel('$X_1$', fontsize = 20)
plt.ylabel('y', rotation= 0, fontsize = 20)
plt.axis([0,2,0,15])
plt.show()

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()

# %%
start = time.time()
time.sleep(1)
lin_reg.fit(X,y)
print('time taken= ', time.time()-start)
# Out:
# time taken=  1.0115642547607422

# %%
lin_reg.intercept_,lin_reg.coef_
# Out:
# (array([4.21509616]), array([[2.77011339]]))

# %%
x_1 = np.array([[1.5],[3.5]])
y_predict = lin_reg.predict(x_1)
y_predict
# Out:
# array([[ 8.37026624],
#        [13.91049301]])

# %%
plt.figure(figsize = (10,7))
plt.plot(x_1,y_predict,'g--')
plt.plot(X_new,y_new,'r-')
plt.plot(X,y,'b.')
plt.xlabel('$X_1$', fontsize = 20)
plt.ylabel('y', rotation= 0, fontsize = 20)
plt.axis([0,5,0,15])
plt.show()

# %%
time.time()
# Out:
# 1613904751.4678392

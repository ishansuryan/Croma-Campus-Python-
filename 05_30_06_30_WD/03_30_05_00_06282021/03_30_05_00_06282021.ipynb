# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
np.random.seed(42)
x = 2*np.random.rand(100,1)-1
y = 4*x -2 + np.random.rand(100,1)

# %%
x_b = np.c_[np.ones((100,1)),x]             # adding bias term
# x_b

# %%
plt.plot(x,y,'b*')
plt.show()

# %%
sol = np.linalg.inv(x_b.T.dot(x_b)).dot(x_b.T).dot(y)

# %%
sol
# Out:
# array([[-1.50316817],
#        [ 3.98323418]])

# %%
x_new = np.linspace(-1,1, 200).reshape(200,1)
x_new_b = np.c_[np.ones((200,1)), x_new]
y_new = x_new_b.dot(sol)

# %%
plt.plot(x,y,'bo')      # scattered points
plt.plot(x_new,y_new,'r-')
plt.show()

# %%
np.random.seed(102)
z = np.random.rand(10)
z
# Out:
# array([0.59768158, 0.6759869 , 0.29928174, 0.73074027, 0.57873939,
#        0.80901767, 0.1672485 , 0.31214497, 0.35793155, 0.4917473 ])

# %% [markdown]
# # Finding the solution from gradient descent

# %%
theta = 0.1
eta= 0.2
m =len(x)
iterations = 1000
for i in range(iterations):
    gradients = 2/m * x_b.T.dot(x_b.dot(theta) -y)
    if i<10:
        print(theta)
    theta = theta - eta *  gradients
# Out:
# 0.1
# [[-0.63628893 -0.59390339]
#  [ 0.70229656  0.68575036]]
# [[-1.06130872 -1.03627211]
#  [ 1.18757881  1.17438678]]
# [[-1.30474399 -1.29003673]
#  [ 1.59400285  1.58327616]]
# [[-1.44110974 -1.43254127]
#  [ 1.93706732  1.92821045]]
# [[-1.51474525 -1.50981545]
#  [ 2.22829852  2.22090025]]
# [[-1.55197912 -1.54919773]
#  [ 2.47653285  2.47029983]]
# [[-1.56839771 -1.56687757]
#  [ 2.68872733  2.68344329]]
# [[-1.57318688 -1.57240084]
#  [ 2.870482    2.86598248]]
# [[-1.57172455 -1.57136026]
#  [ 3.02638475  3.02254114]]

# %%
theta
# Out:
# array([[-1.50316817, -1.50316817],
#        [ 3.98323418,  3.98323418]])

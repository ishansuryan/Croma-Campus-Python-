# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'C:\Croma-Campus-Python-\Data\iris.csv')

# %%
df.head(2)
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal.length  150 non-null    float64
#  1   sepal.width   150 non-null    float64
#  2   petal.length  150 non-null    float64
#  3   petal.width   150 non-null    float64
#  4   variety       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
x = df[df.variety == 'Setosa']
x
# Out:
#     sepal.length  sepal.width  petal.length  petal.width variety
# 0            5.1          3.5           1.4          0.2  Setosa
# 1            4.9          3.0           1.4          0.2  Setosa
# 2            4.7          3.2           1.3          0.2  Setosa
# 3            4.6          3.1           1.5          0.2  Setosa
# 4            5.0          3.6           1.4          0.2  Setosa
# 5            5.4          3.9           1.7          0.4  Setosa
# 6            4.6          3.4           1.4          0.3  Setosa
# 7            5.0          3.4           1.5          0.2  Setosa
# 8            4.4          2.9           1.4          0.2  Setosa
# 9            4.9          3.1           1.5          0.1  Setosa
# 10           5.4          3.7           1.5          0.2  Setosa
# 11           4.8          3.4           1.6          0.2  Setosa
# 12           4.8          3.0           1.4          0.1  Setosa
# ...

# %%
plt.bar(1, df.value_counts('variety'), width = 0.5)  # (position on x axis, Height, width = int/float)
plt.axis([0,10,0,200])
plt.show()

# %%
df.value_counts('variety')
# Out:
# variety
# Virginica     50
# Versicolor    50
# Setosa        50
# dtype: int64

# %%
flowers = ['Virginica','Versicolor','Setosa']
x1 = df[df.variety == 'Setosa']
x2 = df[df.variety =='Versicolor']
x3 = df[df.variety == 'Virginica']
x = 1
for i in flowers:
    plt.bar(x, df[df.variety== i].shape[0], width = 0.5, label = i)
    x +=1

# plt.bar(1, x1.value_counts('variety'), width = 0.5, label = 'Setosa', bottom = 5)
# plt.bar(2, x2.value_counts('variety'), width = 0.5, label = 'Versicolor')
# plt.bar(3, x3.value_counts('variety'), width = 0.5, label = 'Virginica',)
plt.legend()
plt.xlim(0,5)
plt.ylim(0,60)
# plt.axis([0,5,0,60])
plt.show()
# x = 1
# for i in flowers:
#     plt.plot(x, )

# %%
df[df.variety== 'Setosa'].shape[0]
# Out:
# 50

# %%
plt.pie(df.variety.value_counts(), labels=df.variety.unique(), autopct='%.1f', explode= [0.2,0,0], startangle = 0,shadow = True)
plt.show()

# %%
df.variety.unique()
# Out:
# array(['Setosa', 'Versicolor', 'Virginica'], dtype=object)

# %%
plt.hist(df[df.variety=='Setosa']['sepal.width'])
plt.xlabel('Setal Width')
plt.ylabel('Frequency')
plt.show()

# %%
plt.scatter(df[df.variety == 'Setosa']['petal.width'], df[df.variety == 'Setosa']['sepal.width'])
plt.show()

# %%
import seaborn as sns

# %%
sns.scatterplot(df[df.variety == 'Setosa']['petal.width'], df[df.variety == 'Setosa']['sepal.width'],hue=)
# Out:
# <AxesSubplot:xlabel='petal.width', ylabel='sepal.width'>

# %%
plt.boxplot(df['petal.length'],  df['petal.length'].mean(), vert= False, )
plt.show()

# %%
max(df['petal.length'])
# Out:
# 6.9

# %%
df.describe()
# Out:
#        sepal.length  sepal.width  petal.length  petal.width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
x = df.corr()

# %%
x
# Out:
#               sepal.length  sepal.width  petal.length  petal.width
# sepal.length      1.000000    -0.117570      0.871754     0.817941
# sepal.width      -0.117570     1.000000     -0.428440    -0.366126
# petal.length      0.871754    -0.428440      1.000000     0.962865
# petal.width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.heatmap(x);

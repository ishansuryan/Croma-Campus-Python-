# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt

# %%
# model = keras.models.Sequential()
# model.add(keras.layers.Flatten(input_shape = (28,28)))              # input layer
# model.add(keras.layers.Dense(300, activation = 'relu'))             # hidden layer
# model.add(keras.layers.Dense(100, activation = 'relu'))             # hidden layer
# model.add(keras.layers.Dense(10, activation = 'softmax'))           # output layer

# %%
model = keras.models.Sequential([
    keras.layers.Flatten(input_shape = (28,28)),
    keras.layers.Dense(300, activation = 'relu'),
    keras.layers.Dense(100, activation = 'relu'),
    keras.layers.Dense(10,  activation = 'softmax')
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# dense (Dense)                (None, 300)               235500
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               30100
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                1010
# =================================================================
# Total params: 266,610
# Trainable params: 266,610
# Non-trainable params: 0
# _________________________________________________________________

# %%
fashion_mnist = keras.datasets.fashion_mnist

# %%
(x_train_full, y_train_full),(x_test,y_test)= fashion_mnist.load_data()

# %%
plt.imshow(x_train_full[1]);

# %%
x_train_full[0].shape
# Out:
# (28, 28)

# %%
x_valid, x_train = x_train_full[:5000]/255, x_train_full[5000:]/255
y_valid, y_train = y_train_full[:5000]    , y_train_full[5000:]

# %%
plt.imshow(x_valid[1], cmap ='binary');

# %%
class_names = ["T-shirt/top", "Trouser", "Pullover","Dress", "Coat","Sandal", "Shirt", "Sneaker", "Bag", "Ankleboot"]

# %%
model.compile(loss='sparse_categorical_crossentropy', optimizer = 'sgd',metrics = ['accuracy'])

# %%
history = model.fit(x_train,y_train, validation_data=(x_valid,y_valid), epochs = 30)
# Out:
# Epoch 1/30
# 1719/1719 [==============================] - 5s 2ms/step - loss: 1.0011 - accuracy: 0.6772 - val_loss: 0.5075 - val_accuracy: 0.8214
# Epoch 2/30
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.5019 - accuracy: 0.8235 - val_loss: 0.4442 - val_accuracy: 0.8494
# Epoch 3/30
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.4535 - accuracy: 0.8386 - val_loss: 0.4197 - val_accuracy: 0.8578
# Epoch 4/30
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.4240 - accuracy: 0.8498 - val_loss: 0.4142 - val_accuracy: 0.8556
# Epoch 5/30
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3989 - accuracy: 0.8571 - val_loss: 0.3943 - val_accuracy: 0.8626
# Epoch 6/30
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3828 - accuracy: 0.8640 - val_loss: 0.3817 - val_accuracy: 0.8632
# Epoch 7/30
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3600 - accuracy: 0.8720 - val_loss: 0.3700 - val_accuracy: 0.8698
# Epoch 8/30
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3557 - accuracy: 0.8733 - val_loss: 0.3642 - val_accuracy: 0.8722
# Epoch 9/30
# 1719/1719 [==============================] - 2s 991us/step - loss: 0.3411 - accuracy: 0.8791 - val_loss: 0.3509 - val_accuracy: 0.8772
# Epoch 10/30
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3365 - accuracy: 0.8811 - val_loss: 0.3539 - val_accuracy: 0.8766
# Epoch 11/30
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3303 - accuracy: 0.8837 - val_loss: 0.3463 - val_accuracy: 0.8758
# Epoch 12/30
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3145 - accuracy: 0.8884 - val_loss: 0.3399 - val_accuracy: 0.8820
# Epoch 13/30
# 1719/1719 [==============================] - 2s 991us/step - loss: 0.3108 - accuracy: 0.8891 - val_loss: 0.3411 - val_accuracy: 0.8788
# Epoch 14/30
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3060 - accuracy: 0.8897 - val_loss: 0.3301 - val_accuracy: 0.8806
# Epoch 15/30
# 1719/1719 [==============================] - 2s 982us/step - loss: 0.3034 - accuracy: 0.8904 - val_loss: 0.3295 - val_accuracy: 0.8842
# Epoch 16/30
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2878 - accuracy: 0.8974 - val_loss: 0.3269 - val_accuracy: 0.8804
# Epoch 17/30
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2845 - accuracy: 0.8989 - val_loss: 0.3127 - val_accuracy: 0.8872
# Epoch 18/30
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2776 - accuracy: 0.9000 - val_loss: 0.3070 - val_accuracy: 0.8890
# Epoch 19/30
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2777 - accuracy: 0.8992 - val_loss: 0.3144 - val_accuracy: 0.8858
# Epoch 20/30
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2670 - accuracy: 0.9033 - val_loss: 0.3088 - val_accuracy: 0.8906
# Epoch 21/30
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2653 - accuracy: 0.9051 - val_loss: 0.3341 - val_accuracy: 0.8804
# Epoch 22/30
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2588 - accuracy: 0.9053 - val_loss: 0.3073 - val_accuracy: 0.8896
# Epoch 23/30
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2547 - accuracy: 0.9079 - val_loss: 0.3021 - val_accuracy: 0.8914
# Epoch 24/30
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2513 - accuracy: 0.9094 - val_loss: 0.3013 - val_accuracy: 0.8920
# Epoch 25/30
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2450 - accuracy: 0.9119 - val_loss: 0.3183 - val_accuracy: 0.8876
# Epoch 26/30
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2444 - accuracy: 0.9128 - val_loss: 0.3186 - val_accuracy: 0.8818
# Epoch 27/30
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2380 - accuracy: 0.9158 - val_loss: 0.2994 - val_accuracy: 0.8926
# Epoch 28/30
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2327 - accuracy: 0.9172 - val_loss: 0.3053 - val_accuracy: 0.8884
# Epoch 29/30
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2282 - accuracy: 0.9173 - val_loss: 0.2976 - val_accuracy: 0.8950
# Epoch 30/30
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.2313 - accuracy: 0.9184 - val_loss: 0.3082 - val_accuracy: 0.8882

# %%
model.evaluate(x_test,y_test)
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 67.0215 - accuracy: 0.8438
# [67.02145385742188, 0.8438000082969666]

# %%
prediction = model.predict_classes(x_test[0:30])

# %%
rows = 3
cols = 10
plt.figure(figsize = (cols*1.5,rows*1.5,))
for row in range(rows):
    for column in range(cols):
        i = row * cols + column
        plt.subplot(rows,cols,i+1)
        plt.imshow(x_test[i])
        plt.title(class_names[prediction[i]])
        plt.axis('off')
plt.subplots_adjust(wspace = 0.2, hspace = 0.5)
plt.show()

# %%
rows = 3
cols = 10
plt.figure(figsize = (cols*1.5,rows*1.5,))
for row in range(rows):
    for column in range(cols):
        i = row * cols + column
        plt.subplot(rows,cols,i+1)
        plt.imshow(x_test[i])
        plt.title(class_names[y_test[i]])
        plt.axis('off')
plt.subplots_adjust(wspace = 0.2, hspace = 0.5)
plt.show()
